# %% [markdown]
# <a href="https://colab.research.google.com/github/BasmaAlaa-ph/BasmaAlaa-ph/blob/main/Advanced_Oral_Bioavailability_Screening_%7C_Comparative_Analysis_of_Lipinski%2C_Ghose%2C_and_Veber_Rules_Using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# 'properties.csv' is in the root of your Google Drive , (change the path below to where YOU saved tha dataset file)
file_path = '/content/drive/MyDrive/properties.csv'
df = pd.read_csv(file_path)

print('Successfully loaded properties.csv into a DataFrame.')
display(df.head())
# Out:
# Successfully loaded properties.csv into a DataFrame.
#    index row ID                                           Molecule  \
# 0      0   Row0                                                  N
# 1      1   Row1                            O=C(O)c1c(OC(=O)C)cccc1
# 2      2   Row2                                                C#C
# 3      3   Row3  P(=O)(OP(=O)(OC[C@H]1O[C@@H](n2c3ncnc(c3nc2)N)...
# 4      4   Row4  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c...
#
#    Molecule name  Mannhold LogP Atomic Polarizabilities  Aromatic Atoms Count  \
# 0            H3N           1.35                3.100379                     0
# 1         C9H8O4           2.01               24.382344                     6
# 2           C2H2           1.68                4.853586                     0
# 3  C10H16N5O13P3           0.25               55.084688                     9
# 4    C16H19N3O4S           2.34               50.237067                     6
#
#    Aromatic Bonds Count  Element Count Bond Polarizabilities  ...  XLogP  \
# 0                     0              4              1.299621  ...  0.000
# 1                     6             21             12.577656  ...  1.422
# 2                     0              4              2.186414  ...  0.418
# 3                    10             47             55.749312  ... -5.533
# 4                     6             43             27.904933  ... -1.732
#
#    Zagreb Index  Molecular Formula Formal Charge  Formal Charge (pos)  \
# 0             0                H3N             0                    0
# 1            60             C9H8O4             0                    0
# 2             2               C2H2             0                    0
# 3           170      C10H16N5O13P3             0                    0
# 4           132        C16H19N3O4S             0                    0
#
#    Formal Charge (neg)  Heavy Atoms Count  Molar Mass  SP3 Character  \
# 0                    0                  1   17.030525       0.000000
# 1                    0                 13  180.157769       0.047619
# 2                    0                  2   26.037353       0.000000
# 3                    0                 31  507.181476       0.106383
# 4                    0                 24  349.406463       0.162791
#
#    Rotatable Bonds Count (non terminal)
# 0                                     0
# 1                                     3
# 2                                     0
# 3                                     8
# 4                                     4
#
# [5 rows x 34 columns]

# %%
# CELL 1: Initial Inspection
# Quick sanity check: how many rows/columns and what are we working with?

print("Shape of the dataset (rows, columns):", df.shape)
print("\nColumn names:")
print(df.columns.tolist())

df.head()
# Out:
# Shape of the dataset (rows, columns): (15166, 34)
#
# Column names:
# ['index', 'row ID', 'Molecule', 'Molecule name', 'Mannhold LogP', 'Atomic Polarizabilities', 'Aromatic Atoms Count', 'Aromatic Bonds Count', 'Element Count', 'Bond Polarizabilities', 'Bond Count', 'Eccentric Connectivity Index', 'Fragment Complexity', 'VABC Volume Descriptor', 'Hydrogen Bond Acceptors', 'Hydrogen Bond Donors', 'Largest Chain', 'Largest Pi Chain', 'Petitjean Number', 'Rotatable Bonds Count', "Lipinski's Rule of Five", 'Topological Polar Surface Area', 'Vertex adjacency information magnitude', 'Molecular Weight', 'XLogP', 'Zagreb Index', 'Molecular Formula', 'Formal Charge', 'Formal Charge (pos)', 'Formal Charge (neg)', 'Heavy Atoms Count', 'Molar Mass', 'SP3 Character', 'Rotatable Bonds Count (non terminal)']
#    index row ID                                           Molecule  \
# 0      0   Row0                                                  N
# 1      1   Row1                            O=C(O)c1c(OC(=O)C)cccc1
# 2      2   Row2                                                C#C
# 3      3   Row3  P(=O)(OP(=O)(OC[C@H]1O[C@@H](n2c3ncnc(c3nc2)N)...
# 4      4   Row4  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c...
#
#    Molecule name  Mannhold LogP Atomic Polarizabilities  Aromatic Atoms Count  \
# 0            H3N           1.35                3.100379                     0
# 1         C9H8O4           2.01               24.382344                     6
# 2           C2H2           1.68                4.853586                     0
# 3  C10H16N5O13P3           0.25               55.084688                     9
# 4    C16H19N3O4S           2.34               50.237067                     6
#
#    Aromatic Bonds Count  Element Count Bond Polarizabilities  ...  XLogP  \
# 0                     0              4              1.299621  ...  0.000
# 1                     6             21             12.577656  ...  1.422
# 2                     0              4              2.186414  ...  0.418
# 3                    10             47             55.749312  ... -5.533
# 4                     6             43             27.904933  ... -1.732
#
#    Zagreb Index  Molecular Formula Formal Charge  Formal Charge (pos)  \
# 0             0                H3N             0                    0
# 1            60             C9H8O4             0                    0
# 2             2               C2H2             0                    0
# 3           170      C10H16N5O13P3             0                    0
# 4           132        C16H19N3O4S             0                    0
#
#    Formal Charge (neg)  Heavy Atoms Count  Molar Mass  SP3 Character  \
# 0                    0                  1   17.030525       0.000000
# 1                    0                 13  180.157769       0.047619
# 2                    0                  2   26.037353       0.000000
# 3                    0                 31  507.181476       0.106383
# 4                    0                 24  349.406463       0.162791
#
#    Rotatable Bonds Count (non terminal)
# 0                                     0
# 1                                     3
# 2                                     0
# 3                                     8
# 4                                     4
#
# [5 rows x 34 columns]

# %%
# CELL 2: Data Cleaning & Renaming
# "Molecule" column holds SMILES strings, not names — rename for clarity.

df = df.rename(columns={'Molecule': 'SMILES'})

df.head()
# Out:
#    index row ID                                             SMILES  \
# 0      0   Row0                                                  N
# 1      1   Row1                            O=C(O)c1c(OC(=O)C)cccc1
# 2      2   Row2                                                C#C
# 3      3   Row3  P(=O)(OP(=O)(OC[C@H]1O[C@@H](n2c3ncnc(c3nc2)N)...
# 4      4   Row4  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c...
#
#    Molecule name  Mannhold LogP Atomic Polarizabilities  Aromatic Atoms Count  \
# 0            H3N           1.35                3.100379                     0
# 1         C9H8O4           2.01               24.382344                     6
# 2           C2H2           1.68                4.853586                     0
# 3  C10H16N5O13P3           0.25               55.084688                     9
# 4    C16H19N3O4S           2.34               50.237067                     6
#
#    Aromatic Bonds Count  Element Count Bond Polarizabilities  ...  XLogP  \
# 0                     0              4              1.299621  ...  0.000
# 1                     6             21             12.577656  ...  1.422
# 2                     0              4              2.186414  ...  0.418
# 3                    10             47             55.749312  ... -5.533
# 4                     6             43             27.904933  ... -1.732
#
#    Zagreb Index  Molecular Formula Formal Charge  Formal Charge (pos)  \
# 0             0                H3N             0                    0
# 1            60             C9H8O4             0                    0
# 2             2               C2H2             0                    0
# 3           170      C10H16N5O13P3             0                    0
# 4           132        C16H19N3O4S             0                    0
#
#    Formal Charge (neg)  Heavy Atoms Count  Molar Mass  SP3 Character  \
# 0                    0                  1   17.030525       0.000000
# 1                    0                 13  180.157769       0.047619
# 2                    0                  2   26.037353       0.000000
# 3                    0                 31  507.181476       0.106383
# 4                    0                 24  349.406463       0.162791
#
#    Rotatable Bonds Count (non terminal)
# 0                                     0
# 1                                     3
# 2                                     0
# 3                                     8
# 4                                     4
#
# [5 rows x 34 columns]

# %%
# CELL 3: Column Extraction
# Extract only the descriptor columns needed for screening rules.
# .copy() ensures clean_df is truly independent.

clean_df = df[['Molecular Formula', 'XLogP', 'Molecular Weight',
               'Hydrogen Bond Donors', 'Hydrogen Bond Acceptors',
               'SMILES', 'Element Count' ,'Topological Polar Surface Area',
               'Rotatable Bonds Count']].copy()

print("Shape of the updated dataset (rows, columns):", clean_df.shape)
print("\nColumn names:")
print(clean_df.columns.tolist())

clean_df.head(10)
# Out:
# Shape of the updated dataset (rows, columns): (15166, 9)
#
# Column names:
# ['Molecular Formula', 'XLogP', 'Molecular Weight', 'Hydrogen Bond Donors', 'Hydrogen Bond Acceptors', 'SMILES', 'Element Count', 'Topological Polar Surface Area', 'Rotatable Bonds Count']
#   Molecular Formula  XLogP Molecular Weight  Hydrogen Bond Donors  \
# 0               H3N  0.000        17.026549                     1
# 1            C9H8O4  1.422       180.042259                     1
# 2              C2H2  0.418         26.01565                     0
# 3     C10H16N5O13P3 -5.533       506.995745                     7
# 4       C16H19N3O4S -1.732       349.109627                     3
# 5            C6H8O6 -0.178       176.032088                     4
# 6            C6H8O6 -0.178       176.032088                     4
# 7            C9H13N  1.762       135.104799                     1
# 8        C14H18N2O5 -0.077       294.121572                     3
# 9       C16H19N3O5S -2.138       365.104542                     4
#
#    Hydrogen Bond Acceptors                                             SMILES  \
# 0                        1                                                  N
# 1                        3                            O=C(O)c1c(OC(=O)C)cccc1
# 2                        0                                                C#C
# 3                       17  P(=O)(OP(=O)(OC[C@H]1O[C@@H](n2c3ncnc(c3nc2)N)...
# 4                        7  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c...
# 5                        6                    O=C1O[C@H]([C@@H](O)CO)C(=C1O)O
# 6                        6                        O=C1OC([C@@H](O)CO)C(=C1O)O
# 7                        1                                     NC(Cc1ccccc1)C
# 8                        7     O=C(OC)[C@@H](NC(=O)[C@@H](N)CC(=O)O)Cc1ccccc1
# 9                        7  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c...
#
#    Element Count Topological Polar Surface Area  Rotatable Bonds Count
# 0              4                              0                      0
# 1             21                           63.6                      5
# 2              4                              0                      0
# 3             47                         308.56                     15
# 4             43                         138.03                      8
# 5             20                         107.22                      6
# 6             20                         107.22                      6
# 7             23                          26.02                      4
# 8             39                         118.72                     11
# 9             44                         158.26                      9

# %%
columns = clean_df.columns.tolist()
#  Cell 4: Move 'SMILES' column to be after 'Molecular Formula' for logical grouping
columns.remove('SMILES')
columns.insert(columns.index('Molecular Formula') + 1, 'SMILES')

clean_df = clean_df[columns]

clean_df.head()
# Out:
#   Molecular Formula                                             SMILES  XLogP  \
# 0               H3N                                                  N  0.000
# 1            C9H8O4                            O=C(O)c1c(OC(=O)C)cccc1  1.422
# 2              C2H2                                                C#C  0.418
# 3     C10H16N5O13P3  P(=O)(OP(=O)(OC[C@H]1O[C@@H](n2c3ncnc(c3nc2)N)... -5.533
# 4       C16H19N3O4S  S1C([C@H](C(=O)O)N2[C@H]1[C@H](NC(=O)[C@H](N)c... -1.732
#
#   Molecular Weight  Hydrogen Bond Donors  Hydrogen Bond Acceptors  \
# 0        17.026549                     1                        1
# 1       180.042259                     1                        3
# 2         26.01565                     0                        0
# 3       506.995745                     7                       17
# 4       349.109627                     3                        7
#
#    Element Count Topological Polar Surface Area  Rotatable Bonds Count
# 0              4                              0                      0
# 1             21                           63.6                      5
# 2              4                              0                      0
# 3             47                         308.56                     15
# 4             43                         138.03                      8

# %%
# CELL 5: Handling Missing Values (With Conditional Logic)
# Check for NaN values and drop rows if needed.

missing_counts = clean_df.isnull().sum()
print("Missing values per column:")
print(missing_counts)

total_missing = missing_counts.sum()

if total_missing > 0:
    rows_before = clean_df.shape[0]
    clean_df.dropna(inplace=True)
    rows_after = clean_df.shape[0]
    rows_dropped = rows_before - rows_after
    print(f"\nDropped {rows_dropped} rows containing missing values.")
    print(f"Rows remaining: {rows_after}")
else:
    print("\nNo missing values found. Dataset is clean.")
# Out:
# Missing values per column:
# Molecular Formula                 0
# SMILES                            0
# XLogP                             0
# Molecular Weight                  0
# Hydrogen Bond Donors              0
# Hydrogen Bond Acceptors           0
# Element Count                     0
# Topological Polar Surface Area    0
# Rotatable Bonds Count             0
# dtype: int64
#
# No missing values found. Dataset is clean.

# %%
# CELL 6 :Convert numeric columns to proper numeric type.
# CSV imports sometimes store numbers as text — pd.to_numeric() fixes this and coerces errors to NaN.
# This ensures all comparisons in later cells work correctly (e.g., HBD > 5).

clean_df['Hydrogen Bond Donors'] = pd.to_numeric(clean_df['Hydrogen Bond Donors'], errors='coerce')
clean_df['Hydrogen Bond Acceptors'] = pd.to_numeric(clean_df['Hydrogen Bond Acceptors'], errors='coerce')
clean_df['Molecular Weight'] = pd.to_numeric(clean_df['Molecular Weight'], errors='coerce')
clean_df['XLogP'] = pd.to_numeric(clean_df['XLogP'], errors='coerce')
clean_df['Element Count'] = pd.to_numeric(clean_df['Element Count'], errors='coerce')
clean_df['Topological Polar Surface Area'] = pd.to_numeric(clean_df['Topological Polar Surface Area'], errors='coerce')
clean_df['Rotatable Bonds Count'] = pd.to_numeric(clean_df['Rotatable Bonds Count'], errors='coerce')

print("\nNumeric conversion complete. All descriptor columns are ready for calculations.")
# Out:
# Numeric conversion complete. All descriptor columns are ready for calculations.

# %%
# CELL 7: Calculating Violations (The Scientific Logic)
# --- Lipinski's Rule of Five ---
# Classic baseline for oral drug-likeness: HBD/HBA/MW/LogP constraints.
# Counting violations keeps granularity for analysis.

# calculate 'Lipinski_Violations' after ensuring numeric types
clean_df['Lipinski_Violations'] = (
    (clean_df['Hydrogen Bond Donors'] > 5).astype(int) +
    (clean_df['Hydrogen Bond Acceptors'] > 10).astype(int) +
    (clean_df['Molecular Weight'] >= 500).astype(int) +
    (clean_df['XLogP'] > 5).astype(int)
      )

clean_df.sample(10)
# Out:
#       Molecular Formula                                             SMILES  \
# 9454           C14H19NO                          O=C(c1ccccc1)C(N2CCCC2)CC
# 8170       C24H20I6N4O8  Ic1c(NC(=O)CCCCC(=O)Nc2c(I)c(c(I)c(c2I)C(=O)NC...
# 12394      C26H26F6N4O3  FC(F)(F)CC[C@@H](C(=O)N[C@H]1N=C(c2ccccc2N(C1=...
# 6103          C19H21N3O               O=c1n(nc(Cc2ccccc2)c3c1cccc3)CCN(C)C
# 2550        C15H11ClN2O                   Clc1cc2C(=NCC(Nc2cc1)=O)c3ccccc3
# 4612             C8H10O                                        OCCc1ccccc1
# 4249       C16H23BrN2O3         Brc1c(OC)c(c(OC)cc1)C(=O)NC[C@H]2N(CCC2)CC
# 8190         C44H57NO17  O=C1[C@]2([C@@H]([C@@]3(OC(=O)C)[C@H](OC3)C[C@...
# 13981      C27H32ClN5O5  Clc1c(Nc2ncnc3c2c(OC4CCOCC4)cc(OCCN5CCN(C)CC5)...
# 5196           C24H34O2  O=c1occ(C2C3(C(C4C(C5(C(CCCC5)CC4)C)CC3)CC2)C)cc1
#
#        XLogP  Molecular Weight  Hydrogen Bond Donors  Hydrogen Bond Acceptors  \
# 9454   2.814        217.146664                     0                        2
# 8170   7.166       1253.554952                     6                       12
# 12394  5.237        556.190910                     2                        7
# 6103   3.586        307.168462                     0                        2
# 2550   2.776        270.055991                     1                        3
# 4612   1.369        122.073165                     1                        1
# 4249   2.874        370.089205                     1                        3
# 8190   3.178        871.362649                     3                       18
# 13981  2.814        541.209197                     1                        6
# 5196   9.693        354.255880                     0                        0
#
#        Element Count  Topological Polar Surface Area  Rotatable Bonds Count  \
# 9454              35                           20.31                      5
# 8170              62                          191.00                     21
# 12394             65                          104.86                     18
# 6103              44                           38.13                      7
# 2550              30                           41.46                      2
# 4612              19                           20.23                      3
# 4249              45                           50.80                     10
# 8190             119                          245.82                     29
# 13981             70                           90.44                     10
# 5196              60                           30.21                      3
#
#        Lipinski_Violations
# 9454                     0
# 8170                     4
# 12394                    2
# 6103                     0
# 2550                     0
# 4612                     0
# 4249                     0
# 8190                     2
# 13981                    1
# 5196                     1

# %%
# CELL 8 : --- Ghose Filter ---
# Lipinski only flags high LogP, missing hydrophilic extremes.
# Ghose adds strict lower AND upper bounds on LogP (-0.4 to 5.6), MW, and atom count.
# Molar Refractivity omitted: it's redundant with MW + Element Count (both measure bulkiness).

clean_df['Ghose_Violations'] = (
    (~clean_df['XLogP'].between(-0.4, 5.6)).astype(int) +
    (~clean_df['Molecular Weight'].between(160, 480)).astype(int) +
    (~clean_df['Element Count'].between(20, 70)).astype(int)
      )

clean_df.sample(10)
# Out:
#       Molecular Formula                                             SMILES  \
# 13007           C12H8O4                     O=C(O)c1cc2c(cc(C(=O)O)cc2)cc1
# 8661            C15F33N  FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)N(C(F)(F)C...
# 15151            C7H7NO                                     O=Cc1c(N)cccc1
# 9932           C27H30O6  O(c1c(OC)cc2Cc3c(cc(OC)c(c3)OC)Cc4c(Cc2c1)cc(O...
# 477               ClKO3                                [K+].Cl(=O)(=O)[O-]
# 11630            C8H8O2                                  O=C(c1ccc(O)cc1)C
# 11924           C8H10O3                            O=C(OC(=O)C(=C)C)C(=C)C
# 8816         C18H24N4O4       O=C(OC(C)(C)C)N1CCC(OCc2onc(n2)-c3ccncc3)CC1
# 6076       C15H17N7O5S3  S1[C@H]2N(C(C(=O)O)=C(C1)CSc3nnnn3C)C(=O)[C@@]...
# 6632              BF4Na                                 [Na+].F[B-](F)(F)F
#
#         XLogP  Molecular Weight  Hydrogen Bond Donors  \
# 13007   2.518        216.042259                     2
# 8661   14.391        820.950380                     0
# 15151   1.330        121.052764                     1
# 9932    5.120        450.204239                     0
# 477    -0.286        121.917303                     0
# 11630   1.493        136.052429                     1
# 11924   1.637        154.062994                     0
# 8816    2.273        360.179755                     0
# 6076   -0.968        471.045330                     2
# 6632    2.322        109.992688                     0
#
#        Hydrogen Bond Acceptors  Element Count  Topological Polar Surface Area  \
# 13007                        4             24                           74.60
# 8661                         1             49                            3.24
# 15151                        2             16                           43.09
# 9932                         0             63                           55.38
# 477                          3              5                           57.20
# 11630                        1             18                           37.30
# 11924                        3             21                           43.37
# 8816                         6             50                           90.58
# 6076                        11             47                          239.23
# 6632                         0              6                            0.00
#
#        Rotatable Bonds Count  Lipinski_Violations  Ghose_Violations
# 13007                      4                    0                 0
# 8661                      48                    2                 2
# 15151                      2                    0                 2
# 9932                      12                    1                 0
# 477                        1                    0                 2
# 11630                      3                    0                 2
# 11924                      6                    0                 1
# 8816                       9                    0                 0
# 6076                      12                    1                 1
# 6632                       4                    0                 2

# %%
# CELL 9 : --- Veber's Rules ---
# Lipinski/Ghose focus on LogP and size. Veber adds structural angle:
# flexibility (rotatable bonds) and polarity (TPSA) also affect absorption.

clean_df['Veber_Violations'] = (
    (clean_df['Rotatable Bonds Count'] > 10).astype(int) +
    (clean_df['Topological Polar Surface Area'] > 140).astype(int)
     )

clean_df.sample(10)
# Out:
#       Molecular Formula                                             SMILES  \
# 13098         C21H31NO3         O=C1c2c(c(OCC(O)CNC(C)(C)C)ccc2)CC13CCCCC3
# 11913           C6H12O4                            O=C(O)[C@H](O)C(CO)(C)C
# 130          C13H10N2O4                  O=C1NC(=O)CCC1N2C(=O)c3ccccc3C2=O
# 14447        C21H27ClO2  ClC#C[C@@]1(O)[C@@]2([C@H]([C@H]3[C@@H]([C@@H]...
# 5912          C24H31NO4  O(c1c(OCC)cc2CCN\C(\c2c1)=C/c3cc(OCC)c(OCC)cc3)CC
# 4729             C3H8S2                                              SCCCS
# 3751           C16H20N2                       n1c(cccc1)C(c2ccccc2)CCN(C)C
# 7764        C20H37NaO7S  S(=O)(=O)([O-])C(C(=O)OCC(CCCC)CC)CC(=O)OCC(CC...
# 13979       C20H28FN3O3    FCCCCCn1nc(C(=O)N[C@H](C(=O)OCC)C(C)C)c2c1cccc2
# 12553         C16H20N2O  O[C@@H]1[C@@H]2c3c4c([nH]cc4C[C@H]2N(C)C[C@@H]...
#
#        XLogP  Molecular Weight  Hydrogen Bond Donors  Hydrogen Bond Acceptors  \
# 13098  3.593        345.230394                     2                        3
# 11913 -0.673        148.073559                     3                        4
# 130    0.257        258.064057                     1                        6
# 14447  4.597        346.169958                     1                        2
# 5912   5.135        397.225308                     1                        1
# 4729   1.912        108.006742                     0                        0
# 3751   2.616        240.162649                     0                        2
# 7764   5.040        444.215769                     0                        7
# 13979  4.285        377.211470                     1                        5
# 12553  1.811        256.157563                     2                        2
#
#        Element Count  Topological Polar Surface Area  Rotatable Bonds Count  \
# 13098             56                           58.56                     10
# 11913             22                           77.76                      8
# 130               29                           83.55                      1
# 14447             51                           37.30                      3
# 5912              60                           48.95                     13
# 4729              13                           77.60                      4
# 3751              38                           16.13                      7
# 7764              66                          118.18                     23
# 13979             55                           73.22                     15
# 12553             39                           39.26                      3
#
#        Lipinski_Violations  Ghose_Violations  Veber_Violations
# 13098                    0                 0                 0
# 11913                    0                 2                 0
# 130                      0                 0                 0
# 14447                    0                 0                 0
# 5912                     1                 0                 1
# 4729                     0                 2                 0
# 3751                     0                 0                 0
# 7764                     1                 0                 1
# 13979                    0                 0                 1
# 12553                    0                 0                 0

# %%
# CELL 10: Applying Pass/Fail, The Sweet Spot & Consensus Column
# Convert violation counts to ✅/❌ labels for easy scanning and filtering.

clean_df['Lipinski_Pass'] = clean_df['Lipinski_Violations'].apply(
    lambda x : '✅ Pass' if x <= 1 else '❌ Fail'
    )

# Ghose stays strict (zero tolerance) since the rule is already simplified.
clean_df['Ghose_Pass'] = clean_df['Ghose_Violations'].apply(
    lambda x : '✅ Pass' if x == 0 else '❌ Fail'
    )

clean_df['Veber_Pass'] = clean_df['Veber_Violations'].apply(
    lambda x : '✅ Pass' if x == 0 else '❌ Fail'
    )

# Sweet Spot is optimal LogP range, not just acceptable
clean_df['Sweet_Spot_Pass'] = clean_df['XLogP'].apply(
     lambda x: '✅ Pass' if 0.5 < x < 3.5 else '❌ Fail'
    )

# Consensus: pass only if ALL four filters clear simultaneously.
clean_df['All_Rules_Pass'] = clean_df.apply(
      lambda row: '✅ Pass' if (
             row['Lipinski_Pass'] == '✅ Pass' and
             row['Ghose_Pass'] == '✅ Pass' and
             row['Veber_Pass'] == '✅ Pass' and
             row['Sweet_Spot_Pass'] == '✅ Pass'
             )    else '❌ Fail',
      axis=1
            )

clean_df.sample(10)
# Out:
#       Molecular Formula                                             SMILES  \
# 6813           C13H10O3                        O=C(c1ccc(O)cc1)c2ccc(O)cc2
# 12507          C23H38O2        Oc1c(c(O)cc(c1)C(CCCCCC)(C)C)C2CC(CCC2)(C)C
# 10404        C17H18INO3  Ic1c2c3c(O[C@@H]4[C@@]35[C@@H](C=C[C@@H]4O)[C@...
# 5458         C15H14N6O3  O=C1N(Cc2c(ncn2-c3c1cc(N=[N+]=[N-])cc3)C(=O)OCC)C
# 4959           C2H4N2O2                                       O=C(N)C(=O)N
# 9059        C23H25F2N5O  Fc1c(F)ccc(c1)C(=O)NC2CCC(Nc3nc(N(C)C)c4ccccc4...
# 3735               Br3Y                                      [Y](Br)(Br)Br
# 2835       C18H16N2O7S2  S(=O)(=O)(O)C=1C(=O)/C(=N/Nc2c(cc(C)cc2)C)/c3c...
# 11235         C32H39N3O  O=C(NC1c2c(cccc2)CCC1)CCCCCN3CCN(c4c(-c5ccccc5...
# 9406          C16H17NO4         O=C1N(C(=O)CCc2ccccc2)C[C@@H](OC(=O)C)C=C1
#
#        XLogP  Molecular Weight  Hydrogen Bond Donors  Hydrogen Bond Acceptors  \
# 6813   2.764        214.062994                     2                        1
# 12507  9.547        346.287180                     2                        0
# 10404  1.558        411.033141                     2                        2
# 5458   2.802        326.112738                     0                        7
# 4959  -2.144         88.027277                     2                        4
# 9059   5.230        425.202717                     2                        6
# 3735   2.961        325.660860                     0                        0
# 2835   1.869        436.039893                     3                        9
# 11235  6.924        481.309313                     1                        4
# 9406   1.621        287.115758                     0                        5
#
#        Element Count  Topological Polar Surface Area  Rotatable Bonds Count  \
# 6813              26                           57.53                      4
# 12507             63                           40.46                     14
# 10404             40                           52.93                      4
# 5458              38                           76.79                      6
# 4959              10                           86.18                      1
# 9059              56                           70.15                      9
# 3735               4                            0.00                      3
# 2835              45                          166.96                      8
# 11235             75                           35.58                      9
# 9406              38                           63.68                      6
#
#        Lipinski_Violations  Ghose_Violations  Veber_Violations Lipinski_Pass  \
# 6813                     0                 0                 0        ✅ Pass
# 12507                    1                 1                 1        ✅ Pass
# 10404                    0                 0                 0        ✅ Pass
# 5458                     0                 0                 0        ✅ Pass
# 4959                     0                 3                 0        ✅ Pass
# 9059                     1                 0                 0        ✅ Pass
# 3735                     0                 1                 0        ✅ Pass
# 2835                     0                 0                 1        ✅ Pass
# 11235                    1                 3                 0        ✅ Pass
# 9406                     0                 0                 0        ✅ Pass
#
#       Ghose_Pass Veber_Pass Sweet_Spot_Pass All_Rules_Pass
# 6813      ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass
# 12507     ❌ Fail     ❌ Fail          ❌ Fail         ❌ Fail
# 10404     ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass
# 5458      ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass
# 4959      ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 9059      ✅ Pass     ✅ Pass          ❌ Fail         ❌ Fail
# 3735      ❌ Fail     ✅ Pass          ✅ Pass         ❌ Fail
# 2835      ✅ Pass     ❌ Fail          ✅ Pass         ❌ Fail
# 11235     ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 9406      ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass

# %%
# CELL 11: Comparative Summary & Value Counts with Percentages
# How many compounds pass/fail each rule? Shows the effect of tightening criteria.

print("LIPINSKI RULE")
print(" "*60)
lipinski_counts = clean_df['Lipinski_Pass'].value_counts()
print(lipinski_counts)
print("\nPercentages:")
print((lipinski_counts / len(clean_df) * 100).round(2))

print("\n" + "="*60)
print("GHOSE FILTER")
print(" "*60)
ghose_counts = clean_df['Ghose_Pass'].value_counts()
print(ghose_counts)
print("\nPercentages:")
print((ghose_counts / len(clean_df) * 100).round(2))

print("\n" + "="*60)
print("VEBER RULES")
print(" "*60)
veber_counts = clean_df['Veber_Pass'].value_counts()
print(veber_counts)
print("\nPercentages:")
print((veber_counts / len(clean_df) * 100).round(2))

print("\n" + "="*60)
print("SWEET SPOT")
print(" "*60)
sweet_spot_counts = clean_df['Sweet_Spot_Pass'].value_counts()
print(sweet_spot_counts)
print("\nPercentages:")
print((sweet_spot_counts / len(clean_df) * 100).round(2))

print("\n" + "="*60)
print("CONSENSUS (All Rules)")
print(" "*60)
all_rules_counts = clean_df['All_Rules_Pass'].value_counts()
print(all_rules_counts)
print("\nPercentages:")
print((all_rules_counts / len(clean_df) * 100).round(2))

print("\n" + "="*60)
print("Final Results Sample (10 random compounds):")
print(" "*60)
clean_df[['Molecular Formula', 'SMILES',
          'Lipinski_Violations', 'Ghose_Violations', 'Veber_Violations',
          'Lipinski_Pass', 'Ghose_Pass', 'Veber_Pass',
          'Sweet_Spot_Pass', 'All_Rules_Pass']].sample(10)
# Out:
# LIPINSKI RULE
#
# Lipinski_Pass
# ✅ Pass    13681
# ❌ Fail     1485
# Name: count, dtype: int64
#
# Percentages:
# Lipinski_Pass
# ✅ Pass    90.21
# ❌ Fail     9.79
# Name: count, dtype: float64
#
# ============================================================
# GHOSE FILTER
#
# Ghose_Pass
# ❌ Fail    8160
# ✅ Pass    7006
# Name: count, dtype: int64
#
# Percentages:
# Ghose_Pass
# ❌ Fail    53.8
# ✅ Pass    46.2
# Name: count, dtype: float64
#
# ============================================================
# VEBER RULES
#
# Veber_Pass
# ✅ Pass    10915
# ❌ Fail     4251
# Name: count, dtype: int64
#
# Percentages:
# Veber_Pass
# ✅ Pass    71.97
# ❌ Fail    28.03
# Name: count, dtype: float64
#
# ============================================================
# SWEET SPOT
#
# Sweet_Spot_Pass
# ❌ Fail    8473
# ✅ Pass    6693
# Name: count, dtype: int64
#
# Percentages:
# Sweet_Spot_Pass
# ❌ Fail    55.87
# ✅ Pass    44.13
# Name: count, dtype: float64
#
# ============================================================
# CONSENSUS (All Rules)
#
# All_Rules_Pass
# ❌ Fail    11757
# ✅ Pass     3409
# Name: count, dtype: int64
#
# Percentages:
# All_Rules_Pass
# ❌ Fail    77.52
# ✅ Pass    22.48
# Name: count, dtype: float64
#
# ============================================================
# Final Results Sample (10 random compounds):
#       Molecular Formula                                             SMILES  \
# 1621              CdCl2                                 [Cd+2].[Cl-].[Cl-]
# 1721              C3H6O                                            O=C(C)C
# 13363             C3H9N                                             N(CC)C
# 12728         C13H19NO4                      O=C(NCCc1cc(OC)c(OC)c(c1)OC)C
# 12073           C8H10IN                                   Ic1ccc(N(C)C)cc1
# 113                 CHN                                                N#C
# 9181             C4H7N5                                    n1c(nc(C)nc1N)N
# 8241           C24H36O2  O1c2c(c(OC)cc(c2)C(C(CC)C)(C)C)C3CC(C)=CCC3C1(C)C
# 1216             C5H6Si                                    [SiH]1=CC=CC=C1
# 12930             C7H10                                        C=1C=CCCCC1
#
#        Lipinski_Violations  Ghose_Violations  Veber_Violations Lipinski_Pass  \
# 1621                     0                 1                 0        ✅ Pass
# 1721                     0                 2                 0        ✅ Pass
# 13363                    0                 2                 0        ✅ Pass
# 12728                    0                 0                 0        ✅ Pass
# 12073                    0                 0                 0        ✅ Pass
# 113                      0                 2                 0        ✅ Pass
# 9181                     0                 3                 0        ✅ Pass
# 8241                     1                 1                 1        ✅ Pass
# 1216                     0                 2                 0        ✅ Pass
# 12930                    0                 2                 0        ✅ Pass
#
#       Ghose_Pass Veber_Pass Sweet_Spot_Pass All_Rules_Pass
# 1621      ❌ Fail     ✅ Pass          ✅ Pass         ❌ Fail
# 1721      ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 13363     ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 12728     ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass
# 12073     ✅ Pass     ✅ Pass          ✅ Pass         ✅ Pass
# 113       ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 9181      ❌ Fail     ✅ Pass          ❌ Fail         ❌ Fail
# 8241      ❌ Fail     ❌ Fail          ❌ Fail         ❌ Fail
# 1216      ❌ Fail     ✅ Pass          ✅ Pass         ❌ Fail
# 12930     ❌ Fail     ✅ Pass          ✅ Pass         ❌ Fail

# %%
# CELL 12: Exporting Final Report to Google Drive
# Save results to CSV .

clean_df.to_csv('/content/drive/My Drive/Advanced_Drug_Screening_Results.csv', index=False)

print("✅ Exported: Advanced_Drug_Screening_Results.csv")
print("📂 Location : Google Drive > My Drive")
# Out:
# ✅ Exported: Advanced_Drug_Screening_Results.csv
# 📂 Location : Google Drive > My Drive
